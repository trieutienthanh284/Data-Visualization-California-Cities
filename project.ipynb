# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/california_cities.csv')
df.head()
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
df = df.drop(columns = ['area_total_sq_mi', 'area_land_sq_mi', 'area_water_sq_mi', 'elevation_ft'])
df.head()
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  \
# 0           0     Adelanto  34.576111 -117.432778        875.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0
# 2           2      Alameda  37.756111 -122.274444          NaN
# 3           3       Albany  37.886944 -122.297778          NaN
# 4           4     Alhambra  34.081944 -118.135000        150.0
#
#    population_total  area_total_km2  area_land_km2  area_water_km2  \
# 0             31765         145.107        145.062           0.046
# 1             20330          20.260         20.184           0.076
# 2             75467          59.465         27.482          31.983
# 3             18969          14.155          4.632           9.524
# 4             83089          19.766         19.763           0.003
#
#    area_water_percent
# 0                0.03
# 1                0.37
# 2               53.79
# 3               67.28
# 4                0.01

# %%
lat, longd = df['latd'], df['longd']
population = df['population_total']
area = df['area_total_km2']
plt.scatter(longd, lat, c = np.log10(population), cmap = 'viridis',
            s = area, linewidths = 0, alpha = 0.8)
plt.style.use('seaborn-v0_8-darkgrid')
plt.colorbar(label = 'log$_{10}$(population)');
plt.axis('equal');
plt.xlabel('Latitude');
plt.ylabel('Longitude');
plt.clim(2,7)
area_range = [50, 100, 300, 500]
for area in area_range:
    plt.scatter([], [], s = area,
                label = str(area) + 'km$^2$')
plt.legend(labelspacing = 1, title = 'Area');
plt.title('Population and Area Distribtion of California City');
